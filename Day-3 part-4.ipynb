# %% [markdown]
# ## TUPLE

# %%
student_DB = (14, "JAN", 2027)

# %%
type(student_DB)
# Out:
# tuple

# %%
date, month, year = student_DB

# %%
print("Date is", date)
# Out:
# Date is 14

# %%
month = "JAN"
print("Month is", month)
# Out:
# Month is JAN

# %%
YEAR = 2027
print("Year is", year)
# Out:
# Year is 2027

# %%
grades = ("A", "B", "A", "A", "C")

# %%
print(grades.count("A"))
# Out:
# 3

# %%
print(grades.count("C"))
# Out:
# 1

# %%
grades.index("A")
# Out:
# 0

# %%
students = {
    "Name" :  "Rakhi",
    "age" :  29,
    "Course" : "python"
}
print(students["Name"])
print(students["age"])
print(students["Course"])
# Out:
# Rakhi
# 29
# python

# %%
student.keys()
# Out:
# dict_keys(['Name', 'age', 'Course'])

# %%
print(students["age"])
# Out:
# 29

# %%
student = {
    "Name" : "Tom",
    "age" : 29
}

# %%
type(student)
# Out:
# dict

# %%
student["CITY"] = "MUMBAI"

# %%
print(student)
# Out:
# {'Name': 'Tom', 'age': 29, 'CITY': 'MUMBAI'}

# %%
student["age"] = 28

# %%
print(student)
# Out:
# {'Name': 'Tom', 'age': 28, 'CITY': 'MUMBAI'}

# %%
del student["CITY"]

# %%
print(student)
# Out:
# {'Name': 'Tom', 'age': 28}

# %%
for key, value in student.items():
    print("KEY is -->",value)
# Out:
# KEY is --> Tom
# KEY is --> 28

# %%
student.keys()
# Out:
# dict_keys(['Name', 'age'])

# %%
student.values()
# Out:
# dict_values(['Tom', 28])

# %%
print(students.items())
# Out:
# dict_items([('Name', 'Rakhi'), ('age', 29), ('Course', 'python')])

# %%
print(student.get ("Name"))
# Out:
# Tom

# %%
student.update({"age" : 22, "city":"Mumbai"})

# %%
print(student)
# Out:
# {'Name': 'Tom', 'age': 22, 'city': 'Mumbai'}

# %%
student = {
    "city" : "Mumbai"
}
student.pop("city")
# Out:
# 'Mumbai'

# %%
print(student)
# Out:
# {}

# %%
student = {
    "age" : "22"
}
student.popitem()
# Out:
# ('age', '22')

# %%
student = {
    "Name" : "Tom"
}
duplicate_student = student.copy()

# %%
duplicate_student
# Out:
# {'Name': 'Tom'}

# %%
student.clear()

# %%
print(student)
# Out:
# {}

# %%
new_students = {
    "S101" : {"name" : "Tom", "age" : 20, "marks" : 78},
    "S102" : {"name" : "Jack", "age" : 21, "marks" : 88},
    "S103" : {"name" : "Pop", "age" : 19, "marks" : 70}
}

# %%
print(new_students["S102"])
# Out:
# {'name': 'Jack', 'age': 21, 'marks': 88}

# %%
print(new_students["S102"]["name"])
# Out:
# Jack

# %%
print(new_students["S102"]["marks"])
# Out:
# 88

# %%
print(new_students["S102"]["marks"]) == 75
# Out:
# 88
# False

# %%
new_students["S102"]["marks"] = 75

# %%
print(new_students["S102"]["marks"])
# Out:
# 75

# %%
new_students = {
    101: {"name": "Rahul", "marks":85},
    102: {"name": "Priya", "marks": 92},
    103: {"name": "Amit", "marks": 78}
}

for student_id, details in new_students.items():
    print(student_id, "-", details["name"],"-Marks", details["marks"])
# Out:
# 101 - Rahul -Marks 85
# 102 - Priya -Marks 92
# 103 - Amit -Marks 78

# %% [markdown]
# ## SEARCHING

# %%
fruits = {"Apple", "Banana", "Mango"}

# %%
print("Mango" in fruits)
# Out:
# True

# %%
student = {"S102": "Jack", "S101": "Tom", "S103": "Pop"}

# %%
print("S101" in student)
# Out:
# True

# %%
print("S107" in student)
# Out:
# False

# %% [markdown]
# ## MAJOR PROJECT 1

# %%
student = {}


def add_student(student_id, name, marks):
    student[student_id] = {"name": name, "marks": marks}
    print(name, "Added Successfully")


def view_all_students():
    if len(student) == 0:
        print("NO STUDENT FOUND")
        return

    for student_id, details in student.items():
        print(student_id, "-", details["name"], "Marks:", details["marks"])


def search_students(student_id):
    if student_id in student:
        details = student[student_id]
        print("FOUND:", details["name"], "- Marks:", details["marks"])
    else:
        print("NO Student found with id:", student_id)


def show_menu():
    print("""
-------------------------
| 1. Add Students       |
| 2. View All Students  |
| 3. Search Students    |
| 4. Exit               |
-------------------------
""")


def run_program():
    while True:
        show_menu()

        choice = input("Enter Your Choice: ")

        if choice == "1":
            student_id = input("Enter Student ID: ")
            name = input("Enter Student Name: ")
            marks = input("Enter Student Marks: ")

            add_student(student_id, name, marks)

        elif choice == "2":
            view_all_students()

        elif choice == "3":
            student_id = input("Enter Student ID: ")
            search_students(student_id)

        elif choice == "4":
            print("Program Exited")
            break

        else:
            print("Enter Valid Choice from 1 to 4")


run_program()
# Out:
# -------------------------
# | 1. Add Students       |
# | 2. View All Students  |
# | 3. Search Students    |
# | 4. Exit               |
# -------------------------
#
# Enter Valid Choice from 1 to 4
#
# -------------------------
# | 1. Add Students       |
# | 2. View All Students  |
# | 3. Search Students    |
# | 4. Exit               |
# -------------------------
#
# Program Exited
