# %% [markdown]
# ## LIST

# %%
fruits=["Apple","Mango","Cherry","Apple"]

# %%
type(fruits)
# Out:
# list

# %%
fruits
# Out:
# ['Apple', 'Mango', 'Cherry', 'Apple']

# %%
print(fruits[0])
# Out:
# Apple

# %%
print(fruits[1])
# Out:
# Mango

# %%
print(fruits[2])
# Out:
# Cherry

# %%
print(fruits[-1])
# Out:
# Apple

# %%
fruits.append("Pineapple")

# %%
fruits
# Out:
# ['Apple', 'Mango', 'Cherry', 'Apple', 'Pineapple', 'Pineapple']

# %%
fruits.append("Mango")
fruits.remove("Mango")

# %%
fruits
# Out:
# ['Apple', 'Cherry', 'Apple', 'Pineapple', 'Pineapple']

# %%
for i in fruits:
    print(i)
# Out:
# Apple
# Cherry
# Apple
# Pineapple
# Pineapple

# %%
print("Apple" in fruits)
# Out:
# True

# %%
print("Drumstick" in fruits)
# Out:
# False

# %%
fruits.extend(["Orange","Chikoo"])

# %%
fruits
# Out:
# ['Apple', 'Cherry', 'Apple', 'Pineapple', 'Pineapple', 'Orange', 'Chikoo']

# %%
fruits.insert(6,"Green_Apple")

# %%
fruits
# Out:
# ['Apple',
#  'Cherry',
#  'Apple',
#  'Pineapple',
#  'Pineapple',
#  'Orange',
#  'Green_Apple',
#  'Chikoo']

# %%
fruits.remove("Chikoo")

# %%
fruits
# Out:
# ['Apple', 'Cherry', 'Apple', 'Pineapple', 'Pineapple', 'Orange', 'Green_Apple']

# %%
fruits.clear()

# %%
fruits
# Out:
# []

# %%
fruits=["Apple","Mango","Cherry","Grapes","Apple"]

# %%
fruits
# Out:
# ['Apple', 'Mango', 'Cherry', 'Grapes', 'Apple']

# %%
fruits.index("Mango")
# Out:
# 1

# %%
fruits.index("Apple")
# Out:
# 0

# %%
fruits.count("Apple")
# Out:
# 2

# %%
fruits.sort()

# %%
fruits
# Out:
# ['Apple', 'Apple', 'Cherry', 'Grapes', 'Mango']

# %%
fruits.reverse()

# %%
fruits
# Out:
# ['Mango', 'Grapes', 'Cherry', 'Apple', 'Apple']

# %%
duplicate_fruits=fruits.copy()

# %%
duplicate_fruits
# Out:
# ['Mango', 'Grapes', 'Cherry', 'Apple', 'Apple']
