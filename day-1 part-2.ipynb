# %% [markdown]
# ## COMPARISON OPERATOR

# %%
a=10

# %%
b=20

# %%
print(a==b)
# Out:
# False

# %%
print(a>b)
# Out:
# False

# %%
print(b>a)
# Out:
# True

# %%
print(a>=b)
# Out:
# False

# %%
print(a<=b)
# Out:
# True

# %%
print(a!=b)
# Out:
# True

# %%
age=20

# %%
movie_ticket=False

# %%
print(age >18 and movie_ticket)
# Out:
# False

# %%
print(age>18 or movie_ticket)
# Out:
# True

# %% [markdown]
# ## MEMBERSHIP OPERATOR

# %%
fruits="Apple"

# %%
print("a" in fruits)
# Out:
# False

# %%
print("z"in fruits)
# Out:
# False

# %%
print("x" not in fruits)
# Out:
# True

# %% [markdown]
# ## IDENTITY OPERATOR

# %%
a=[1,2,3]

# %%
b=a

# %%
print(b)
# Out:
# [1, 2, 3]

# %%
c=[1,2,3]

# %%
print(a is b)
# Out:
# True

# %%
print(a is c)
# Out:
# False

# %%
print(a==c)
# Out:
# True

# %% [markdown]
# ## BITWISE OPERATOR

# %%
a=5

# %%
b=3

# %%
print(a&b)
# Out:
# 0

# %%
a=6

# %%
b=3

# %%
print(a&b)
# Out:
# 2

# %%
print(a|b)
# Out:
# 7

# %%
print(a^b)
# Out:
# 5

# %% [markdown]
# ## STRING OPERATIONS

# %%
text="Welcome to Linux World Family from Rakhi"

# %%
print(len(text))
# Out:
# 40

# %%
print(text.upper())
# Out:
# WELCOME TO LINUX WORLD FAMILY FROM RAKHI

# %%
print(text.lower())
# Out:
# welcome to linux world family from rakhi

# %%
print(text.title())
# Out:
# Welcome To Linux World Family From Rakhi

# %%
print(text.strip())
# Out:
# Welcome to linux world family from Rakhi

# %%
print(text.replace("Rakhi","LW"))
# Out:
# Welcome to linux world family from LW

# %%
print(text.count("w"))
# Out:
# 1

# %%
print(text.count("W"))
# Out:
# 1

# %%
print(text.count("o"))
# Out:
# 4

# %%
print(text.count("O"))
# Out:
# 0

# %%
print(text.find("Linux"))
# Out:
# -1

# %% [markdown]
# ## SLICING OPERATIONS

# %%
text
# Out:
# 'Welcome to linux world family from Rakhi'

# %%
WORD="PYTHON"

# %%
WORD ="PYTHON"
print(WORD[0])
# Out:
# P

# %%
print(WORD[1])
# Out:
# Y

# %%
print(WORD[-1])
# Out:
# N

# %%
print(WORD[0:2])
# Out:
# PY

# %%
print(WORD[:2])
# Out:
# PY

# %%
print(WORD[:])
# Out:
# PYTHON

# %%
print(WORD[2:])
# Out:
# THON

# %% [markdown]
# ## F STRING OPERATIONS

# %%
name="JACK"

# %%
print("The name of student is name")
# Out:
# The name of student is name

# %%
print(f"The name of student is {name}")
# Out:
# The name of student is JACK

# %%
print(f"The name of student is {name}.The age of student is {age}")
# Out:
# The name of student is JACK.The age of student is 20

# %%
Exp=20
name="Rakhi"
print("My name is", name,"Exp is",Exp)
# Out:
# My name is Rakhi Exp is 20

# %%
print(f"My name is {name}.Exp is {Exp}")
# Out:
# My name is Rakhi.Exp is 20
